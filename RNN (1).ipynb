# %% [markdown]
# ```
# # This is formatted as code
# ```
# Recurrent neural network (RNN) Use the Google stock prices dataset and design a time series analysis and prediction system using RNN.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/Google_Stock_Price_Train.csv",index_col='Date',parse_dates=True)
data
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21   6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24   5,405,900
# 2012-01-09  322.04  322.29  309.46  620.76  11,688,800
# ...            ...     ...     ...     ...         ...
# 2016-12-23  790.90  792.74  787.28  789.91     623,400
# 2016-12-27  790.68  797.86  787.66  791.55     789,100
# 2016-12-28  793.70  794.23  783.20  785.05   1,153,800
# 2016-12-29  783.33  785.93  778.92  782.79     744,300
# 2016-12-30  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2012-01-03 to 2016-12-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1258 non-null   float64
#  1   High    1258 non-null   float64
#  2   Low     1258 non-null   float64
#  3   Close   1258 non-null   object
#  4   Volume  1258 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 59.0+ KB

# %%
data['Open'].plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %%
data['Close']=data['Close'].str.replace(',','').astype(float)

# %%
data['Volume']=data['Volume'].str.replace(',','').astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2012-01-03 to 2016-12-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1258 non-null   float64
#  1   High    1258 non-null   float64
#  2   Low     1258 non-null   float64
#  3   Close   1258 non-null   float64
#  4   Volume  1258 non-null   float64
# dtypes: float64(5)
# memory usage: 59.0 KB

# %%
data.rolling(5).mean()
# Out:
# <ipython-input-62-9b19add94925>:1: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Date'], dtype='object')
#   data.rolling(5).mean()
#          Open     High      Low    Close     Volume
# 0         NaN      NaN      NaN      NaN        NaN
# 1         NaN      NaN      NaN      NaN        NaN
# 2         NaN      NaN      NaN      NaN        NaN
# 3         NaN      NaN      NaN      NaN        NaN
# 4     327.346  329.702  322.816  651.250  7362980.0
# ...       ...      ...      ...      ...        ...
# 1253  793.216  795.810  788.500  793.270   998000.0
# 1254  793.308  795.850  788.778  792.740   909400.0
# 1255  792.696  794.966  786.764  790.466   949960.0
# 1256  790.194  792.816  785.128  788.112   856560.0
# 1257  788.272  790.708  781.494  784.224  1016120.0
#
# [1258 rows x 5 columns]

# %%
data['Open'].plot(figsize=(16,6))
data.rolling(17).mean()['Close'].plot()
# Out:
# <ipython-input-63-6ce279f84fdc>:2: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Date'], dtype='object')
#   data.rolling(17).mean()['Close'].plot()
# <Axes: >

# %%
train_set=data['Open']
train_set=pd.DataFrame(train_set)
train_set.shape
# Out:
# (1258, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler(feature_range=(0,1))
train_Set_sc=sc.fit_transform(train_set)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.metrics import r2_score

# %%
#data=pd.read_csv("/content/Google_Stock_Price_Train.csv",index_col='Date',parse_dates=True)
data=pd.read_csv("/content/Google_Stock_Price_Train.csv")
data
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]

# %%
data['Close']=data['Close'].str.replace(',','').astype(float)
data['Volume']=data['Volume'].str.replace(',','').astype(float)

# %% [markdown]
# In the dataset, the Volume column had thousand seperated values, which is taken as string when usually loading to Pandas DataFrame. I have specified that ',' is used as the thousand separator when loading, so that the ',' will not be there when loading to our program. Then it'll be loaded as a numerical value.
#
# Plotting the Data

# %%
ax1 = data.plot(x="Date", y=["Open", "High", "Low", "Close"],  figsize=(18,10),title='Open, High, Low, Close Stock Prices of Google Stocks')
ax1.set_ylabel("Stock Price")

ax2 = data.plot(x="Date", y=["Volume"],  figsize=(18,9))
ax2.set_ylabel("Stock Volume")
# Out:
# Text(0, 0.5, 'Stock Volume')

# %% [markdown]
# When inspecting the first plot, we can see that in the closing value of stock prior to 2014/03/26, there is a significant gap between the closing price and the other prices, where as after this date, the closing price has also been closer to other prices.
#
# When inspecting the second plot, we can see that there are significant fluctuations in the Stock Volume over the time. And it is quite hard to find a trend/pattern in this the data in Stock Volume (the one we need to predict).
#
# Preprocessing Data
# Preprocessing data includes handling missing values and outliers, applying feature coding techniques if needed, scale & standardize features.
#
# Checking for Missing values

# %%
# Getting a summary of missing values for each field/attribute
print(data.isnull().sum())
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# We can see that there are no missing values in the dataset.
#
# Handling Outliers
#
# According to the above graph plots that indicate the Open, High, Low and Close values of the Stock prices, the Close price is as mentioned earlier, has a significant gap with the other values. The surprising fact is that, the Close value has even become higher than the High value (highest price of stock for a given day), which is not real.
#
# Ref: https://www.mit.edu/~mbarker/formula1/f1help/11-ch-10.htm
#
# Let us also check outliers for attributes by using box plots as follows.

# %%
data[['Open','High','Low','Close','Volume']].plot(kind= 'box' ,layout=(1,5),subplots=True, sharex=False, sharey=False, figsize=(20,6),color='blue')
plt.show()

# %% [markdown]
# We can see that there are outliers in the Close and Volume attributes. However, i will not remove any outliers here since there are only a limited number of datapoints (less than 1300) and if we remove outliers, the dataset will become even smaller.
#
# Feature Encoding
#
# When we check the 1st 10 records of the dataset, we could see that all the data in the dataset are numerical data, and there are no categorical data that needs encoding. Therefore, no feature encoding process was carried out on this dataset.
#
# Feature Scaling
#
# MinMaxScaler, which is said to be better to be used with time-series data, was used on this dataset for the feature scaling purposes.
#
# https://machinelearningmastery.com/normalize-standardize-time-series-data-python/
#
# The following set of graphs show the attribute histogram before scaling

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>],
#        [<Axes: title={'center': 'Low'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'Volume'}>, <Axes: >]], dtype=object)

# %%
data
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7380500.0
# 1       1/4/2012  331.27  333.87  329.08  666.45   5749400.0
# 2       1/5/2012  329.83  330.75  326.89  657.21   6590300.0
# 3       1/6/2012  328.34  328.77  323.68  648.24   5405900.0
# 4       1/9/2012  322.04  322.29  309.46  620.76  11688800.0
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91    623400.0
# 1254  12/27/2016  790.68  797.86  787.66  791.55    789100.0
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1153800.0
# 1256  12/29/2016  783.33  785.93  778.92  782.79    744300.0
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1770000.0
#
# [1258 rows x 6 columns]

# %%
scaler = MinMaxScaler()
data_without_date = data[['Open','High','Low','Close','Volume']]
data_scaled = pd.DataFrame(scaler.fit_transform(data_without_date))

# %%
data_scaled
# Out:
#              0         1         2         3         4
# 0     0.085814  0.096401  0.090449  0.237573  0.295258
# 1     0.097012  0.098344  0.098235  0.241514  0.229936
# 2     0.094334  0.092517  0.094086  0.228781  0.263612
# 3     0.091562  0.088819  0.088006  0.216419  0.216179
# 4     0.079842  0.076718  0.061070  0.178548  0.467797
# ...        ...       ...       ...       ...       ...
# 1253  0.952043  0.955292  0.966169  0.411656  0.024650
# 1254  0.951633  0.964853  0.966889  0.413916  0.031286
# 1255  0.957251  0.958074  0.958441  0.404958  0.045891
# 1256  0.937960  0.942574  0.950333  0.401844  0.029491
# 1257  0.936881  0.936691  0.934214  0.386726  0.070569
#
# [1258 rows x 5 columns]

# %%
data_scaled.hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>],
#        [<Axes: title={'center': '4'}>, <Axes: >]], dtype=object)

# %% [markdown]
# Feature Engineering
# Drawing the Correlation Matrix Correlation Coefficient checking mechanism checks the relationship between the different features with the predicting attribute.

# %%
plt.figure(figsize=(6,6))
sns.heatmap(data.corr())
# Out:
# <ipython-input-46-373595b0d5cd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %% [markdown]
# We can see from the correlation matrix that the features Open, High, and Low, all are highly correlated with each other. Therefore, it is sufficient to consider only one feature from the above 3 features and remove the rest.
#
# Furthermore, I am removing the Close field since it contains many abnormal data values, which is like a contexual outlier.

# %%
data_scaled=data_scaled.drop([1,2,4], axis=1)
data_scaled
# Out:
#              0         3
# 0     0.085814  0.237573
# 1     0.097012  0.241514
# 2     0.094334  0.228781
# 3     0.091562  0.216419
# 4     0.079842  0.178548
# ...        ...       ...
# 1253  0.952043  0.411656
# 1254  0.951633  0.413916
# 1255  0.957251  0.404958
# 1256  0.937960  0.401844
# 1257  0.936881  0.386726
#
# [1258 rows x 2 columns]

# %% [markdown]
# Developing the RNN Model
#
# When developing an RNN Model, we have to reshape the data that we are feeding into the model. To do that, first we have to find a pattern in the data available and define the number of timesteps according to the pattern.
#
# When considering the plots we have created for this we could not see a clear cut pattern/trend in the data by just visual inspection. Therefore, I have taken the following code snippet to split the data into a sequence by trying to identify any pattern available.
#
# Since there are two features in our dataset after cleaning, I have used a split sequence method for a multivariate dataset.

# %%
def split_seq_multivariate(sequence, n_past, n_future):

    '''
    n_past ==> no of past observations
    n_future ==> no of future observations
    '''
    x, y = [], []
    for window_start in range(len(sequence)):
        past_end = window_start + n_past
        future_end = past_end + n_future
        if future_end > len(sequence):
            break
        # slicing the past and future parts of the window
        past   = sequence[window_start:past_end, :]
        future = sequence[past_end:future_end, -1]
        x.append(past)
        y.append(future)

    return np.array(x), np.array(y)

# %% [markdown]
# In RNN, since we are dealing with time series data, we have to specify how many past data points we will be considering when generating the sequence.
#
# In here, i have taken 60 past data points (time steps) when generating the data sequences.

# %%
# specify the window size
n_steps = 60

data_scaled = data_scaled.to_numpy()
data_scaled.shape
# Out:
# (1258, 2)

# %% [markdown]
# Next, I am using the split_seq_multivariate function to split the dataset into sequences.

# %%
# split into samples
X, y = split_seq_multivariate(data_scaled, n_steps,1)

# %%
X[1].shape
# Out:
# (60, 2)

# %%
y
# Out:
# array([0.21420007, 0.20434657, 0.21216047, ..., 0.40495845, 0.40184391,
#        0.38672602])

# %%
# X is in the shape of [samples, timesteps, features]
print(X.shape)
print(y.shape)

# make y to the shape of [samples]
y=y[:,0]
y.shape
# Out:
# (1198, 60, 2)
# (1198, 1)
# (1198,)

# %% [markdown]
# Splitting the Data
#
# In this step, I will be splitting the sequenced data into train and test sections with 0.2 test size.
#
# Furthermore, i have split the training set again to train and validation data. I have not used the test data to do the validation because validation data are used to fine tune the model, and if i used the testing data for validation purposes, then those data will be already seen by the model when trying to predict them later.
#
# Ref: https://machinelearningmastery.com/difference-test-validation-datasets/

# %%
# split into train/test
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=50)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (958, 60, 2) (240, 60, 2) (958,) (240,)

# %%
# further dividing the training set into train and validation data
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.2,random_state=30)

print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (766, 60, 2) (192, 60, 2) (766,) (192,)

# %% [markdown]
# Next I am defining the model using Tensorflow Keras LSTM and Dense layers.
#
# In the LSTM layer, i have not specified the activation function explicitly because in the Keras Documentation it is specified that the default activation function for LSTM is tanh and default recurrent activation function is sigmoid. Therefore those default acivation functions will be used here.
#
# Ref: https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTMCell
#
# Define Model

# %%
# define RNN model
model = Sequential()
model.add(LSTM(612, input_shape=(n_steps,2)))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(1))

# %% [markdown]
# The following code line gives a summary of the model we have created, mentioning each layers information.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 612)               1505520
#
#  dense_4 (Dense)             (None, 50)                30650
#
#  dense_5 (Dense)             (None, 50)                2550
#
#  dense_6 (Dense)             (None, 30)                1530
#
#  dense_7 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,540,281
# Trainable params: 1,540,281
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compiling and Training the Model
#
# Next we will be compiling and fitting the model with the training data, and using the validation data to fine tune our model.

# %%
# compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# fit the model
history = model.fit(X_train, y_train, epochs=250, batch_size=32, verbose=2, validation_data=(X_val, y_val))  # has used mini batch learning, with batch_s
# Out:
# Epoch 1/250
# 24/24 - 4s - loss: 0.0483 - mae: 0.1523 - val_loss: 0.0162 - val_mae: 0.0954 - 4s/epoch - 157ms/step
# Epoch 2/250
# 24/24 - 0s - loss: 0.0110 - mae: 0.0763 - val_loss: 0.0051 - val_mae: 0.0403 - 384ms/epoch - 16ms/step
# Epoch 3/250
# 24/24 - 0s - loss: 0.0031 - mae: 0.0280 - val_loss: 0.0037 - val_mae: 0.0268 - 371ms/epoch - 15ms/step
# Epoch 4/250
# 24/24 - 0s - loss: 0.0030 - mae: 0.0309 - val_loss: 0.0047 - val_mae: 0.0366 - 366ms/epoch - 15ms/step
# Epoch 5/250
# 24/24 - 0s - loss: 0.0024 - mae: 0.0232 - val_loss: 0.0037 - val_mae: 0.0294 - 371ms/epoch - 15ms/step
# Epoch 6/250
# 24/24 - 0s - loss: 0.0022 - mae: 0.0250 - val_loss: 0.0033 - val_mae: 0.0341 - 376ms/epoch - 16ms/step
# Epoch 7/250
# 24/24 - 0s - loss: 0.0020 - mae: 0.0225 - val_loss: 0.0030 - val_mae: 0.0298 - 374ms/epoch - 16ms/step
# Epoch 8/250
# 24/24 - 0s - loss: 0.0021 - mae: 0.0252 - val_loss: 0.0026 - val_mae: 0.0246 - 346ms/epoch - 14ms/step
# Epoch 9/250
# 24/24 - 0s - loss: 0.0020 - mae: 0.0227 - val_loss: 0.0029 - val_mae: 0.0342 - 366ms/epoch - 15ms/step
# Epoch 10/250
# 24/24 - 0s - loss: 0.0019 - mae: 0.0230 - val_loss: 0.0030 - val_mae: 0.0320 - 332ms/epoch - 14ms/step
# Epoch 11/250
# 24/24 - 0s - loss: 0.0018 - mae: 0.0218 - val_loss: 0.0024 - val_mae: 0.0221 - 339ms/epoch - 14ms/step
# Epoch 12/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0178 - val_loss: 0.0021 - val_mae: 0.0227 - 337ms/epoch - 14ms/step
# Epoch 13/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0173 - val_loss: 0.0025 - val_mae: 0.0351 - 368ms/epoch - 15ms/step
# Epoch 14/250
# 24/24 - 0s - loss: 0.0019 - mae: 0.0227 - val_loss: 0.0018 - val_mae: 0.0203 - 332ms/epoch - 14ms/step
# Epoch 15/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0165 - val_loss: 0.0025 - val_mae: 0.0354 - 334ms/epoch - 14ms/step
# Epoch 16/250
# 24/24 - 0s - loss: 0.0017 - mae: 0.0217 - val_loss: 0.0018 - val_mae: 0.0204 - 372ms/epoch - 16ms/step
# Epoch 17/250
# 24/24 - 0s - loss: 0.0016 - mae: 0.0202 - val_loss: 0.0014 - val_mae: 0.0190 - 335ms/epoch - 14ms/step
# Epoch 18/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0157 - val_loss: 0.0020 - val_mae: 0.0298 - 369ms/epoch - 15ms/step
# Epoch 19/250
# 24/24 - 0s - loss: 0.0017 - mae: 0.0235 - val_loss: 0.0016 - val_mae: 0.0244 - 378ms/epoch - 16ms/step
# Epoch 20/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0198 - val_loss: 0.0013 - val_mae: 0.0210 - 366ms/epoch - 15ms/step
# Epoch 21/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0181 - val_loss: 0.0020 - val_mae: 0.0265 - 337ms/epoch - 14ms/step
# Epoch 22/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0190 - val_loss: 0.0014 - val_mae: 0.0186 - 338ms/epoch - 14ms/step
# Epoch 23/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0176 - val_loss: 0.0014 - val_mae: 0.0197 - 369ms/epoch - 15ms/step
# Epoch 24/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0191 - val_loss: 0.0017 - val_mae: 0.0188 - 338ms/epoch - 14ms/step
# Epoch 25/250
# 24/24 - 0s - loss: 0.0016 - mae: 0.0199 - val_loss: 0.0014 - val_mae: 0.0208 - 376ms/epoch - 16ms/step
# Epoch 26/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0016 - val_mae: 0.0234 - 368ms/epoch - 15ms/step
# Epoch 27/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0186 - val_loss: 0.0014 - val_mae: 0.0222 - 350ms/epoch - 15ms/step
# Epoch 28/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0194 - val_loss: 0.0018 - val_mae: 0.0244 - 368ms/epoch - 15ms/step
# Epoch 29/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0163 - val_loss: 0.0015 - val_mae: 0.0223 - 337ms/epoch - 14ms/step
# Epoch 30/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0192 - val_loss: 0.0013 - val_mae: 0.0200 - 335ms/epoch - 14ms/step
# Epoch 31/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0187 - val_loss: 0.0012 - val_mae: 0.0178 - 373ms/epoch - 16ms/step
# Epoch 32/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0185 - val_loss: 0.0012 - val_mae: 0.0169 - 366ms/epoch - 15ms/step
# Epoch 33/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0158 - val_loss: 0.0013 - val_mae: 0.0209 - 378ms/epoch - 16ms/step
# Epoch 34/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0187 - val_loss: 0.0011 - val_mae: 0.0187 - 370ms/epoch - 15ms/step
# Epoch 35/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0171 - val_loss: 0.0011 - val_mae: 0.0180 - 373ms/epoch - 16ms/step
# Epoch 36/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0167 - val_loss: 0.0011 - val_mae: 0.0178 - 401ms/epoch - 17ms/step
# Epoch 37/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0187 - val_loss: 0.0011 - val_mae: 0.0186 - 369ms/epoch - 15ms/step
# Epoch 38/250
# 24/24 - 0s - loss: 0.0016 - mae: 0.0204 - val_loss: 0.0015 - val_mae: 0.0252 - 403ms/epoch - 17ms/step
# Epoch 39/250
# 24/24 - 0s - loss: 0.0019 - mae: 0.0243 - val_loss: 0.0010 - val_mae: 0.0180 - 373ms/epoch - 16ms/step
# Epoch 40/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0012 - val_mae: 0.0191 - 391ms/epoch - 16ms/step
# Epoch 41/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0189 - val_loss: 0.0013 - val_mae: 0.0231 - 361ms/epoch - 15ms/step
# Epoch 42/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0206 - val_loss: 0.0010 - val_mae: 0.0201 - 338ms/epoch - 14ms/step
# Epoch 43/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0148 - val_loss: 0.0011 - val_mae: 0.0215 - 346ms/epoch - 14ms/step
# Epoch 44/250
# 24/24 - 0s - loss: 0.0017 - mae: 0.0232 - val_loss: 0.0011 - val_mae: 0.0183 - 371ms/epoch - 15ms/step
# Epoch 45/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0197 - val_loss: 0.0011 - val_mae: 0.0172 - 379ms/epoch - 16ms/step
# Epoch 46/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0174 - val_loss: 9.3219e-04 - val_mae: 0.0155 - 343ms/epoch - 14ms/step
# Epoch 47/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0164 - val_loss: 8.4737e-04 - val_mae: 0.0148 - 370ms/epoch - 15ms/step
# Epoch 48/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0217 - 378ms/epoch - 16ms/step
# Epoch 49/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0173 - val_loss: 8.1786e-04 - val_mae: 0.0147 - 379ms/epoch - 16ms/step
# Epoch 50/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0150 - val_loss: 8.9510e-04 - val_mae: 0.0175 - 365ms/epoch - 15ms/step
# Epoch 51/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0155 - val_loss: 7.7974e-04 - val_mae: 0.0156 - 375ms/epoch - 16ms/step
# Epoch 52/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0168 - val_loss: 7.2276e-04 - val_mae: 0.0160 - 346ms/epoch - 14ms/step
# Epoch 53/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0167 - val_loss: 6.8309e-04 - val_mae: 0.0167 - 369ms/epoch - 15ms/step
# Epoch 54/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0175 - val_loss: 5.5750e-04 - val_mae: 0.0139 - 336ms/epoch - 14ms/step
# Epoch 55/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0151 - val_loss: 7.7968e-04 - val_mae: 0.0187 - 372ms/epoch - 15ms/step
# Epoch 56/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0168 - val_loss: 0.0011 - val_mae: 0.0250 - 374ms/epoch - 16ms/step
# Epoch 57/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0157 - val_loss: 6.0680e-04 - val_mae: 0.0149 - 334ms/epoch - 14ms/step
# Epoch 58/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0189 - val_loss: 9.1286e-04 - val_mae: 0.0227 - 343ms/epoch - 14ms/step
# Epoch 59/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0166 - val_loss: 5.0555e-04 - val_mae: 0.0147 - 374ms/epoch - 16ms/step
# Epoch 60/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0144 - val_loss: 5.6441e-04 - val_mae: 0.0158 - 346ms/epoch - 14ms/step
# Epoch 61/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0179 - val_loss: 8.1918e-04 - val_mae: 0.0204 - 368ms/epoch - 15ms/step
# Epoch 62/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0186 - val_loss: 6.1895e-04 - val_mae: 0.0143 - 374ms/epoch - 16ms/step
# Epoch 63/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0160 - val_loss: 0.0011 - val_mae: 0.0247 - 346ms/epoch - 14ms/step
# Epoch 64/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0149 - val_loss: 4.6871e-04 - val_mae: 0.0134 - 340ms/epoch - 14ms/step
# Epoch 65/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0140 - val_loss: 9.3831e-04 - val_mae: 0.0222 - 343ms/epoch - 14ms/step
# Epoch 66/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0205 - val_loss: 5.6013e-04 - val_mae: 0.0161 - 343ms/epoch - 14ms/step
# Epoch 67/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0178 - val_loss: 4.2340e-04 - val_mae: 0.0133 - 375ms/epoch - 16ms/step
# Epoch 68/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0151 - val_loss: 5.0274e-04 - val_mae: 0.0145 - 376ms/epoch - 16ms/step
# Epoch 69/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0164 - val_loss: 0.0011 - val_mae: 0.0273 - 417ms/epoch - 17ms/step
# Epoch 70/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0161 - val_loss: 6.2540e-04 - val_mae: 0.0170 - 389ms/epoch - 16ms/step
# Epoch 71/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0174 - val_loss: 5.4170e-04 - val_mae: 0.0169 - 389ms/epoch - 16ms/step
# Epoch 72/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0165 - val_loss: 8.2687e-04 - val_mae: 0.0231 - 380ms/epoch - 16ms/step
# Epoch 73/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0177 - val_loss: 6.3770e-04 - val_mae: 0.0182 - 384ms/epoch - 16ms/step
# Epoch 74/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0185 - val_loss: 5.9980e-04 - val_mae: 0.0180 - 395ms/epoch - 16ms/step
# Epoch 75/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0153 - val_loss: 3.4783e-04 - val_mae: 0.0127 - 376ms/epoch - 16ms/step
# Epoch 76/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0142 - val_loss: 3.2186e-04 - val_mae: 0.0123 - 341ms/epoch - 14ms/step
# Epoch 77/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0133 - val_loss: 4.0960e-04 - val_mae: 0.0143 - 371ms/epoch - 15ms/step
# Epoch 78/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0157 - val_loss: 4.5454e-04 - val_mae: 0.0154 - 343ms/epoch - 14ms/step
# Epoch 79/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0162 - val_loss: 3.0244e-04 - val_mae: 0.0121 - 376ms/epoch - 16ms/step
# Epoch 80/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0133 - val_loss: 4.4895e-04 - val_mae: 0.0163 - 336ms/epoch - 14ms/step
# Epoch 81/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0154 - val_loss: 3.0419e-04 - val_mae: 0.0122 - 347ms/epoch - 14ms/step
# Epoch 82/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0164 - val_loss: 2.8956e-04 - val_mae: 0.0122 - 341ms/epoch - 14ms/step
# Epoch 83/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0178 - val_loss: 4.8400e-04 - val_mae: 0.0179 - 378ms/epoch - 16ms/step
# Epoch 84/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0155 - val_loss: 2.6447e-04 - val_mae: 0.0120 - 379ms/epoch - 16ms/step
# Epoch 85/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0127 - val_loss: 3.3284e-04 - val_mae: 0.0130 - 344ms/epoch - 14ms/step
# Epoch 86/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0171 - val_loss: 3.2034e-04 - val_mae: 0.0136 - 378ms/epoch - 16ms/step
# Epoch 87/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0170 - val_loss: 3.1936e-04 - val_mae: 0.0129 - 339ms/epoch - 14ms/step
# Epoch 88/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0177 - val_loss: 2.7742e-04 - val_mae: 0.0126 - 374ms/epoch - 16ms/step
# Epoch 89/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0170 - val_loss: 3.0045e-04 - val_mae: 0.0129 - 371ms/epoch - 15ms/step
# Epoch 90/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0157 - val_loss: 7.1209e-04 - val_mae: 0.0227 - 374ms/epoch - 16ms/step
# Epoch 91/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0159 - val_loss: 3.3187e-04 - val_mae: 0.0130 - 342ms/epoch - 14ms/step
# Epoch 92/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0150 - val_loss: 2.6020e-04 - val_mae: 0.0121 - 350ms/epoch - 15ms/step
# Epoch 93/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0163 - val_loss: 2.6157e-04 - val_mae: 0.0116 - 375ms/epoch - 16ms/step
# Epoch 94/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0144 - val_loss: 3.4217e-04 - val_mae: 0.0138 - 377ms/epoch - 16ms/step
# Epoch 95/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0138 - val_loss: 2.8045e-04 - val_mae: 0.0131 - 349ms/epoch - 15ms/step
# Epoch 96/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0136 - val_loss: 2.9762e-04 - val_mae: 0.0124 - 380ms/epoch - 16ms/step
# Epoch 97/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0184 - val_loss: 3.0620e-04 - val_mae: 0.0132 - 373ms/epoch - 16ms/step
# Epoch 98/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0132 - val_loss: 3.5489e-04 - val_mae: 0.0141 - 337ms/epoch - 14ms/step
# Epoch 99/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0161 - val_loss: 2.8692e-04 - val_mae: 0.0122 - 382ms/epoch - 16ms/step
# Epoch 100/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0147 - val_loss: 2.7292e-04 - val_mae: 0.0121 - 345ms/epoch - 14ms/step
# Epoch 101/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0136 - val_loss: 7.4438e-04 - val_mae: 0.0220 - 372ms/epoch - 15ms/step
# Epoch 102/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0182 - val_loss: 2.3598e-04 - val_mae: 0.0118 - 398ms/epoch - 17ms/step
# Epoch 103/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0164 - val_loss: 3.4565e-04 - val_mae: 0.0142 - 367ms/epoch - 15ms/step
# Epoch 104/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0158 - val_loss: 0.0012 - val_mae: 0.0319 - 382ms/epoch - 16ms/step
# Epoch 105/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0156 - val_loss: 2.4684e-04 - val_mae: 0.0117 - 375ms/epoch - 16ms/step
# Epoch 106/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0128 - val_loss: 6.7095e-04 - val_mae: 0.0191 - 411ms/epoch - 17ms/step
# Epoch 107/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0159 - val_loss: 2.5682e-04 - val_mae: 0.0122 - 393ms/epoch - 16ms/step
# Epoch 108/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0156 - val_loss: 3.5333e-04 - val_mae: 0.0148 - 342ms/epoch - 14ms/step
# Epoch 109/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0147 - val_loss: 5.1267e-04 - val_mae: 0.0192 - 344ms/epoch - 14ms/step
# Epoch 110/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0161 - val_loss: 4.2120e-04 - val_mae: 0.0146 - 379ms/epoch - 16ms/step
# Epoch 111/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0143 - val_loss: 2.6004e-04 - val_mae: 0.0119 - 339ms/epoch - 14ms/step
# Epoch 112/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0141 - val_loss: 6.1375e-04 - val_mae: 0.0216 - 339ms/epoch - 14ms/step
# Epoch 113/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0158 - val_loss: 5.0160e-04 - val_mae: 0.0165 - 380ms/epoch - 16ms/step
# Epoch 114/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0140 - val_loss: 6.0151e-04 - val_mae: 0.0184 - 339ms/epoch - 14ms/step
# Epoch 115/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0214 - val_loss: 2.3249e-04 - val_mae: 0.0113 - 342ms/epoch - 14ms/step
# Epoch 116/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0161 - val_loss: 2.9293e-04 - val_mae: 0.0141 - 378ms/epoch - 16ms/step
# Epoch 117/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0148 - val_loss: 6.8759e-04 - val_mae: 0.0229 - 345ms/epoch - 14ms/step
# Epoch 118/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0157 - val_loss: 3.3583e-04 - val_mae: 0.0143 - 342ms/epoch - 14ms/step
# Epoch 119/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0168 - val_loss: 7.8006e-04 - val_mae: 0.0241 - 343ms/epoch - 14ms/step
# Epoch 120/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0146 - val_loss: 2.7992e-04 - val_mae: 0.0121 - 374ms/epoch - 16ms/step
# Epoch 121/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0161 - val_loss: 2.9091e-04 - val_mae: 0.0124 - 350ms/epoch - 15ms/step
# Epoch 122/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0215 - val_loss: 2.4253e-04 - val_mae: 0.0119 - 343ms/epoch - 14ms/step
# Epoch 123/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0165 - val_loss: 3.7787e-04 - val_mae: 0.0144 - 374ms/epoch - 16ms/step
# Epoch 124/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0164 - val_loss: 3.0850e-04 - val_mae: 0.0127 - 341ms/epoch - 14ms/step
# Epoch 125/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0147 - val_loss: 8.4578e-04 - val_mae: 0.0226 - 366ms/epoch - 15ms/step
# Epoch 126/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0186 - val_loss: 8.1782e-04 - val_mae: 0.0232 - 378ms/epoch - 16ms/step
# Epoch 127/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0187 - val_loss: 8.8478e-04 - val_mae: 0.0224 - 349ms/epoch - 15ms/step
# Epoch 128/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0184 - val_loss: 4.8154e-04 - val_mae: 0.0153 - 371ms/epoch - 15ms/step
# Epoch 129/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0147 - val_loss: 3.4656e-04 - val_mae: 0.0143 - 348ms/epoch - 15ms/step
# Epoch 130/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0149 - val_loss: 2.0807e-04 - val_mae: 0.0106 - 369ms/epoch - 15ms/step
# Epoch 131/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0141 - val_loss: 2.5626e-04 - val_mae: 0.0127 - 376ms/epoch - 16ms/step
# Epoch 132/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0149 - val_loss: 3.0364e-04 - val_mae: 0.0132 - 371ms/epoch - 15ms/step
# Epoch 133/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0131 - val_loss: 3.3996e-04 - val_mae: 0.0144 - 341ms/epoch - 14ms/step
# Epoch 134/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0172 - val_loss: 5.9343e-04 - val_mae: 0.0210 - 342ms/epoch - 14ms/step
# Epoch 135/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0156 - val_loss: 3.0634e-04 - val_mae: 0.0137 - 373ms/epoch - 16ms/step
# Epoch 136/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0147 - val_loss: 3.3079e-04 - val_mae: 0.0141 - 389ms/epoch - 16ms/step
# Epoch 137/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0136 - val_loss: 4.1521e-04 - val_mae: 0.0145 - 381ms/epoch - 16ms/step
# Epoch 138/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0156 - val_loss: 2.7088e-04 - val_mae: 0.0115 - 381ms/epoch - 16ms/step
# Epoch 139/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0151 - val_loss: 3.3984e-04 - val_mae: 0.0139 - 388ms/epoch - 16ms/step
# Epoch 140/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0183 - val_loss: 5.8216e-04 - val_mae: 0.0201 - 377ms/epoch - 16ms/step
# Epoch 141/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0190 - val_loss: 4.2094e-04 - val_mae: 0.0166 - 374ms/epoch - 16ms/step
# Epoch 142/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0187 - val_loss: 2.9884e-04 - val_mae: 0.0128 - 370ms/epoch - 15ms/step
# Epoch 143/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0136 - val_loss: 2.6186e-04 - val_mae: 0.0124 - 344ms/epoch - 14ms/step
# Epoch 144/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0154 - val_loss: 4.4052e-04 - val_mae: 0.0171 - 375ms/epoch - 16ms/step
# Epoch 145/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0149 - val_loss: 2.7535e-04 - val_mae: 0.0123 - 343ms/epoch - 14ms/step
# Epoch 146/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0124 - val_loss: 6.0128e-04 - val_mae: 0.0184 - 344ms/epoch - 14ms/step
# Epoch 147/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0185 - val_loss: 2.6429e-04 - val_mae: 0.0121 - 369ms/epoch - 15ms/step
# Epoch 148/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0125 - val_loss: 7.8451e-04 - val_mae: 0.0213 - 338ms/epoch - 14ms/step
# Epoch 149/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0138 - val_loss: 5.5176e-04 - val_mae: 0.0179 - 347ms/epoch - 14ms/step
# Epoch 150/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0167 - val_loss: 2.5285e-04 - val_mae: 0.0113 - 344ms/epoch - 14ms/step
# Epoch 151/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0158 - val_loss: 2.9014e-04 - val_mae: 0.0130 - 343ms/epoch - 14ms/step
# Epoch 152/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0156 - val_loss: 2.4670e-04 - val_mae: 0.0114 - 345ms/epoch - 14ms/step
# Epoch 153/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0141 - val_loss: 2.8974e-04 - val_mae: 0.0133 - 343ms/epoch - 14ms/step
# Epoch 154/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0164 - val_loss: 2.6859e-04 - val_mae: 0.0120 - 376ms/epoch - 16ms/step
# Epoch 155/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0152 - val_loss: 3.6899e-04 - val_mae: 0.0151 - 347ms/epoch - 14ms/step
# Epoch 156/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0139 - val_loss: 3.9878e-04 - val_mae: 0.0156 - 338ms/epoch - 14ms/step
# Epoch 157/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0186 - val_loss: 4.2227e-04 - val_mae: 0.0163 - 375ms/epoch - 16ms/step
# Epoch 158/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0141 - val_loss: 3.5691e-04 - val_mae: 0.0133 - 379ms/epoch - 16ms/step
# Epoch 159/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0169 - val_loss: 3.7819e-04 - val_mae: 0.0143 - 371ms/epoch - 15ms/step
# Epoch 160/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0127 - val_loss: 3.2198e-04 - val_mae: 0.0124 - 383ms/epoch - 16ms/step
# Epoch 161/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0130 - val_loss: 5.5306e-04 - val_mae: 0.0166 - 341ms/epoch - 14ms/step
# Epoch 162/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0148 - val_loss: 6.2476e-04 - val_mae: 0.0201 - 373ms/epoch - 16ms/step
# Epoch 163/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0170 - val_loss: 7.2566e-04 - val_mae: 0.0215 - 369ms/epoch - 15ms/step
# Epoch 164/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0183 - val_loss: 3.8496e-04 - val_mae: 0.0146 - 368ms/epoch - 15ms/step
# Epoch 165/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0151 - val_loss: 3.6213e-04 - val_mae: 0.0142 - 347ms/epoch - 14ms/step
# Epoch 166/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0125 - val_loss: 6.6734e-04 - val_mae: 0.0182 - 343ms/epoch - 14ms/step
# Epoch 167/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0170 - val_loss: 5.3092e-04 - val_mae: 0.0154 - 338ms/epoch - 14ms/step
# Epoch 168/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0175 - val_loss: 4.2072e-04 - val_mae: 0.0155 - 358ms/epoch - 15ms/step
# Epoch 169/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0146 - val_loss: 3.0088e-04 - val_mae: 0.0124 - 381ms/epoch - 16ms/step
# Epoch 170/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0135 - val_loss: 8.4023e-04 - val_mae: 0.0217 - 402ms/epoch - 17ms/step
# Epoch 171/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0196 - val_loss: 8.1423e-04 - val_mae: 0.0203 - 377ms/epoch - 16ms/step
# Epoch 172/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0155 - val_loss: 3.0673e-04 - val_mae: 0.0129 - 373ms/epoch - 16ms/step
# Epoch 173/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0147 - val_loss: 2.8857e-04 - val_mae: 0.0126 - 370ms/epoch - 15ms/step
# Epoch 174/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0154 - val_loss: 2.6224e-04 - val_mae: 0.0114 - 354ms/epoch - 15ms/step
# Epoch 175/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0144 - val_loss: 3.1321e-04 - val_mae: 0.0126 - 367ms/epoch - 15ms/step
# Epoch 176/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0154 - val_loss: 3.4604e-04 - val_mae: 0.0131 - 341ms/epoch - 14ms/step
# Epoch 177/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0152 - val_loss: 3.3707e-04 - val_mae: 0.0135 - 374ms/epoch - 16ms/step
# Epoch 178/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0146 - val_loss: 3.2514e-04 - val_mae: 0.0137 - 350ms/epoch - 15ms/step
# Epoch 179/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0126 - val_loss: 3.9362e-04 - val_mae: 0.0150 - 339ms/epoch - 14ms/step
# Epoch 180/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0137 - val_loss: 4.2479e-04 - val_mae: 0.0143 - 339ms/epoch - 14ms/step
# Epoch 181/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0179 - val_loss: 3.3669e-04 - val_mae: 0.0133 - 366ms/epoch - 15ms/step
# Epoch 182/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0193 - val_loss: 3.4015e-04 - val_mae: 0.0130 - 342ms/epoch - 14ms/step
# Epoch 183/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0156 - val_loss: 4.1761e-04 - val_mae: 0.0150 - 352ms/epoch - 15ms/step
# Epoch 184/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0145 - val_loss: 4.3568e-04 - val_mae: 0.0157 - 373ms/epoch - 16ms/step
# Epoch 185/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0195 - val_loss: 3.3902e-04 - val_mae: 0.0129 - 340ms/epoch - 14ms/step
# Epoch 186/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0145 - val_loss: 3.3529e-04 - val_mae: 0.0131 - 336ms/epoch - 14ms/step
# Epoch 187/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0164 - val_loss: 4.6621e-04 - val_mae: 0.0154 - 370ms/epoch - 15ms/step
# Epoch 188/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0136 - val_loss: 6.8348e-04 - val_mae: 0.0220 - 368ms/epoch - 15ms/step
# Epoch 189/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0188 - val_loss: 6.0892e-04 - val_mae: 0.0183 - 379ms/epoch - 16ms/step
# Epoch 190/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0155 - val_loss: 3.6869e-04 - val_mae: 0.0142 - 347ms/epoch - 14ms/step
# Epoch 191/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0170 - val_loss: 3.2537e-04 - val_mae: 0.0123 - 372ms/epoch - 16ms/step
# Epoch 192/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0136 - val_loss: 4.0570e-04 - val_mae: 0.0144 - 334ms/epoch - 14ms/step
# Epoch 193/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0175 - val_loss: 6.7464e-04 - val_mae: 0.0206 - 337ms/epoch - 14ms/step
# Epoch 194/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0139 - val_loss: 2.9651e-04 - val_mae: 0.0113 - 340ms/epoch - 14ms/step
# Epoch 195/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0152 - val_loss: 5.6793e-04 - val_mae: 0.0156 - 376ms/epoch - 16ms/step
# Epoch 196/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0159 - val_loss: 4.9855e-04 - val_mae: 0.0150 - 339ms/epoch - 14ms/step
# Epoch 197/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0168 - val_loss: 5.8004e-04 - val_mae: 0.0187 - 374ms/epoch - 16ms/step
# Epoch 198/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0164 - val_loss: 3.6956e-04 - val_mae: 0.0137 - 334ms/epoch - 14ms/step
# Epoch 199/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0190 - val_loss: 6.1458e-04 - val_mae: 0.0186 - 368ms/epoch - 15ms/step
# Epoch 200/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0159 - val_loss: 3.6796e-04 - val_mae: 0.0135 - 335ms/epoch - 14ms/step
# Epoch 201/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0141 - val_loss: 3.9660e-04 - val_mae: 0.0137 - 362ms/epoch - 15ms/step
# Epoch 202/250
# 24/24 - 0s - loss: 9.6768e-04 - mae: 0.0118 - val_loss: 5.3099e-04 - val_mae: 0.0162 - 384ms/epoch - 16ms/step
# Epoch 203/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0145 - val_loss: 3.2992e-04 - val_mae: 0.0121 - 395ms/epoch - 16ms/step
# Epoch 204/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0131 - val_loss: 4.6130e-04 - val_mae: 0.0162 - 405ms/epoch - 17ms/step
# Epoch 205/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0152 - val_loss: 7.3117e-04 - val_mae: 0.0221 - 366ms/epoch - 15ms/step
# Epoch 206/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0164 - val_loss: 3.4259e-04 - val_mae: 0.0125 - 365ms/epoch - 15ms/step
# Epoch 207/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0141 - val_loss: 4.0737e-04 - val_mae: 0.0139 - 374ms/epoch - 16ms/step
# Epoch 208/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0130 - val_loss: 4.5198e-04 - val_mae: 0.0138 - 340ms/epoch - 14ms/step
# Epoch 209/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0138 - val_loss: 5.4376e-04 - val_mae: 0.0173 - 348ms/epoch - 14ms/step
# Epoch 210/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0199 - val_loss: 6.1408e-04 - val_mae: 0.0191 - 369ms/epoch - 15ms/step
# Epoch 211/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0149 - val_loss: 3.6012e-04 - val_mae: 0.0134 - 339ms/epoch - 14ms/step
# Epoch 212/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0142 - val_loss: 3.8693e-04 - val_mae: 0.0136 - 348ms/epoch - 14ms/step
# Epoch 213/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0142 - val_loss: 3.7634e-04 - val_mae: 0.0137 - 342ms/epoch - 14ms/step
# Epoch 214/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0169 - val_loss: 3.7173e-04 - val_mae: 0.0134 - 340ms/epoch - 14ms/step
# Epoch 215/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0147 - val_loss: 3.5751e-04 - val_mae: 0.0134 - 343ms/epoch - 14ms/step
# Epoch 216/250
# 24/24 - 0s - loss: 9.8845e-04 - mae: 0.0123 - val_loss: 6.2202e-04 - val_mae: 0.0191 - 343ms/epoch - 14ms/step
# Epoch 217/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0199 - val_loss: 3.4075e-04 - val_mae: 0.0127 - 337ms/epoch - 14ms/step
# Epoch 218/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0137 - val_loss: 3.8028e-04 - val_mae: 0.0132 - 343ms/epoch - 14ms/step
# Epoch 219/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0137 - val_loss: 3.9220e-04 - val_mae: 0.0144 - 368ms/epoch - 15ms/step
# Epoch 220/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0141 - val_loss: 4.2196e-04 - val_mae: 0.0145 - 367ms/epoch - 15ms/step
# Epoch 221/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0146 - val_loss: 4.1542e-04 - val_mae: 0.0147 - 333ms/epoch - 14ms/step
# Epoch 222/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0151 - val_loss: 3.7630e-04 - val_mae: 0.0134 - 340ms/epoch - 14ms/step
# Epoch 223/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0171 - val_loss: 4.4239e-04 - val_mae: 0.0142 - 369ms/epoch - 15ms/step
# Epoch 224/250
# 24/24 - 0s - loss: 9.7859e-04 - mae: 0.0120 - val_loss: 3.9012e-04 - val_mae: 0.0134 - 373ms/epoch - 16ms/step
# Epoch 225/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0153 - val_loss: 7.8486e-04 - val_mae: 0.0221 - 341ms/epoch - 14ms/step
# Epoch 226/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0133 - val_loss: 6.8377e-04 - val_mae: 0.0175 - 333ms/epoch - 14ms/step
# Epoch 227/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0180 - val_loss: 5.6027e-04 - val_mae: 0.0163 - 345ms/epoch - 14ms/step
# Epoch 228/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0141 - val_loss: 7.9825e-04 - val_mae: 0.0230 - 340ms/epoch - 14ms/step
# Epoch 229/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0210 - val_loss: 8.2448e-04 - val_mae: 0.0212 - 340ms/epoch - 14ms/step
# Epoch 230/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0176 - val_loss: 3.5135e-04 - val_mae: 0.0127 - 340ms/epoch - 14ms/step
# Epoch 231/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0139 - val_loss: 3.6328e-04 - val_mae: 0.0130 - 346ms/epoch - 14ms/step
# Epoch 232/250
# 24/24 - 0s - loss: 9.6820e-04 - mae: 0.0122 - val_loss: 7.8716e-04 - val_mae: 0.0201 - 368ms/epoch - 15ms/step
# Epoch 233/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0158 - val_loss: 5.2850e-04 - val_mae: 0.0154 - 337ms/epoch - 14ms/step
# Epoch 234/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0149 - val_loss: 5.7617e-04 - val_mae: 0.0184 - 365ms/epoch - 15ms/step
# Epoch 235/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0134 - val_loss: 5.8444e-04 - val_mae: 0.0158 - 340ms/epoch - 14ms/step
# Epoch 236/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0156 - val_loss: 6.9662e-04 - val_mae: 0.0203 - 397ms/epoch - 17ms/step
# Epoch 237/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0141 - val_loss: 4.1227e-04 - val_mae: 0.0144 - 372ms/epoch - 15ms/step
# Epoch 238/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0147 - val_loss: 3.3933e-04 - val_mae: 0.0122 - 399ms/epoch - 17ms/step
# Epoch 239/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0132 - val_loss: 4.0267e-04 - val_mae: 0.0136 - 401ms/epoch - 17ms/step
# Epoch 240/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0154 - val_loss: 4.5358e-04 - val_mae: 0.0146 - 370ms/epoch - 15ms/step
# Epoch 241/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0153 - val_loss: 4.0270e-04 - val_mae: 0.0137 - 374ms/epoch - 16ms/step
# Epoch 242/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0139 - val_loss: 7.6419e-04 - val_mae: 0.0195 - 343ms/epoch - 14ms/step
# Epoch 243/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0161 - val_loss: 4.0910e-04 - val_mae: 0.0134 - 367ms/epoch - 15ms/step
# Epoch 244/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0145 - val_loss: 5.3662e-04 - val_mae: 0.0164 - 333ms/epoch - 14ms/step
# Epoch 245/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0172 - val_loss: 3.9088e-04 - val_mae: 0.0129 - 336ms/epoch - 14ms/step
# Epoch 246/250
# 24/24 - 0s - loss: 9.8841e-04 - mae: 0.0143 - val_loss: 4.0763e-04 - val_mae: 0.0137 - 338ms/epoch - 14ms/step
# Epoch 247/250
# 24/24 - 0s - loss: 9.9589e-04 - mae: 0.0139 - val_loss: 4.0293e-04 - val_mae: 0.0143 - 336ms/epoch - 14ms/step
# Epoch 248/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0145 - val_loss: 4.9655e-04 - val_mae: 0.0168 - 332ms/epoch - 14ms/step
# Epoch 249/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0148 - val_loss: 4.1223e-04 - val_mae: 0.0131 - 366ms/epoch - 15ms/step
# Epoch 250/250
# 24/24 - 0s - loss: 9.3219e-04 - mae: 0.0121 - val_loss: 4.6395e-04 - val_mae: 0.0141 - 337ms/epoch - 14ms/step

# %%
from matplotlib import pyplot
# plot learning curves
pyplot.title('Learning Curves')
pyplot.xlabel('Epoch')
pyplot.ylabel('Root Mean Squared Error')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='val')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Model Evaluation and Predictions
#
# Next, i will be using the model.evaluate() and model.predict() methods.
#
# The model.evaluate() is used to only check the MSE, RMSE, MAE values of our model when the testing data is used. This does not provide us with the results the model would predict. Therefore to see the results that the model would predict, i have used the model.predict() function. Later I have plotted the actual and predicted values of the test data to see how well our model has performed.
#
# Ref: https://stackoverflow.com/questions/44476706/what-is-the-difference-between-keras-model-evaluate-and-model-predict

# %%
# evaluate the model
mse, mae = model.evaluate(X_test, y_test, verbose=0)
print('MSE: %.3f, RMSE: %.3f, MAE: %.3f' % (mse, np.sqrt(mse), mae))
# Out:
# MSE: 0.001, RMSE: 0.023, MAE: 0.016

# %%
# predicting y_test values
print(X_test.shape)
predicted_values = model.predict(X_test)
print(predicted_values.shape)
# print(predicted_values)
# Out:
# (240, 60, 2)
# 8/8 [==============================] - 0s 7ms/step
# (240, 1)

# %%
plt.plot(y_test,c = 'r')
plt.plot(predicted_values,c = 'y')
plt.xlabel('Day')
plt.ylabel('Stock Price Volume')
plt.title('Stock Price Volume Prediction Graph using RNN (LSTM)')
plt.legend(['Actual','Predicted'],loc = 'lower right')
plt.figure(figsize=(10,6))

# %% [markdown]
# Using R Squared
#
# The R squared is a metric we can use to evaluate how well our regression based (model that handle continuous data) have performed.
#
# R squared can vary between 0 and 1 and we can evaluate our model using this metric, while a negative value would mean that the training has not been done properly.

# %%
# evaluating using R squared
R_square = r2_score(y_test, predicted_values)

print(R_square)
# Out:
# 0.9921751571910027
